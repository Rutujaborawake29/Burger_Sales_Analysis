# %% [markdown]
# <a href="https://colab.research.google.com/github/Rutujaborawake29/Burger_Sales_Analysis/blob/main/Burger_sales_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
from google.colab import files
upload=files.upload()
# Out:
#      <input type="file" id="files-4d5d9506-707a-4343-9a3c-bb65f41642d1" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-4d5d9506-707a-4343-9a3c-bb65f41642d1">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
data=pd.read_excel('food (1).xlsx')

# %%
data.head(5)
# Out:
#   f_id                  item veg_or_non_veg
# 0  fd0     Aloo Tikki Burger            Veg
# 1  fd1     Veg Creamy Burger            Veg
# 2  fd2   Cheese Burst Burger            Veg
# 3  fd3  Paneer Creamy Burger            Veg
# 4  fd4        Maxican Burger            Veg

# %%
data.tail(5)
# Out:
#              f_id                    item veg_or_non_veg
# 371555  fd1048555    Sizzlers De- Verdure            Veg
# 371556  fd1048556         Veg Bbq Sizzler            Veg
# 371557  fd1048558    Veg Sizzling Italian            Veg
# 371558  fd1048561  Veg Overload  Sandwich            Veg
# 371559  fd1048562    Aglio Riso Rice Bowl            Veg
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_0.groupby('f_id').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_1.groupby('item').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 371560 entries, 0 to 371559
# Data columns (total 3 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   f_id            371552 non-null  object
#  1   item            371552 non-null  object
#  2   veg_or_non_veg  371552 non-null  object
# dtypes: object(3)
# memory usage: 8.5+ MB

# %%
data.shape
# Out:
# (371560, 3)

# %%
data.describe()
# Out:
#           f_id               item veg_or_non_veg
# count   371552             371552         371552
# unique  371552             369347              2
# top        fd0  Aloo Tikki Burger            Veg
# freq         1                  2         270768

# %%
data.columns
# Out:
# Index(['f_id', 'item', 'veg_or_non_veg'], dtype='object')

# %%
data.size
# Out:
# 1114680

# %%
data.isnull()
# Out:
#          f_id   item  veg_or_non_veg
# 0       False  False           False
# 1       False  False           False
# 2       False  False           False
# 3       False  False           False
# 4       False  False           False
# ...       ...    ...             ...
# 371555  False  False           False
# 371556  False  False           False
# 371557  False  False           False
# 371558  False  False           False
# 371559  False  False           False
#
# [371560 rows x 3 columns]

# %%
data.isnull().sum()
# Out:
# f_id              8
# item              8
# veg_or_non_veg    8
# dtype: int64

# %%
data.dropna()
# Out:
#              f_id                    item veg_or_non_veg
# 0             fd0       Aloo Tikki Burger            Veg
# 1             fd1       Veg Creamy Burger            Veg
# 2             fd2     Cheese Burst Burger            Veg
# 3             fd3    Paneer Creamy Burger            Veg
# 4             fd4          Maxican Burger            Veg
# ...           ...                     ...            ...
# 371555  fd1048555    Sizzlers De- Verdure            Veg
# 371556  fd1048556         Veg Bbq Sizzler            Veg
# 371557  fd1048558    Veg Sizzling Italian            Veg
# 371558  fd1048561  Veg Overload  Sandwich            Veg
# 371559  fd1048562    Aglio Riso Rice Bowl            Veg
#
# [371552 rows x 3 columns]

# %%
duplicates = data.duplicated()
print(duplicates)
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 371555    False
# 371556    False
# 371557    False
# 371558    False
# 371559    False
# Length: 371560, dtype: bool

# %%
duplicates = data.duplicated().sum()
print(duplicates)
# Out:
# 7

# %%
data.drop_duplicates()
# Out:
#              f_id                    item veg_or_non_veg
# 0             fd0       Aloo Tikki Burger            Veg
# 1             fd1       Veg Creamy Burger            Veg
# 2             fd2     Cheese Burst Burger            Veg
# 3             fd3    Paneer Creamy Burger            Veg
# 4             fd4          Maxican Burger            Veg
# ...           ...                     ...            ...
# 371555  fd1048555    Sizzlers De- Verdure            Veg
# 371556  fd1048556         Veg Bbq Sizzler            Veg
# 371557  fd1048558    Veg Sizzling Italian            Veg
# 371558  fd1048561  Veg Overload  Sandwich            Veg
# 371559  fd1048562    Aglio Riso Rice Bowl            Veg
#
# [371553 rows x 3 columns]

# %%
data.shape
# Out:
# (371560, 3)

# %%
from matplotlib import pyplot as plt
import seaborn as sns
data.groupby('veg_or_non_veg').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
plt.gca().spines[['top', 'right',]].set_visible(False)
